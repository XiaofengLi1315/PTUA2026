# %% [markdown]
# # Lab 06 Web Scrapping

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import ast
from pandas import json_normalize
from tqdm import tqdm
import folium

# %% [markdown]
# ## Starbucks store locator
#
# - Website: https://www.starbucks.co.uk/store-locator?types=starbucks&latLng=55.8625388%2C-4.284226000000002&zoom=12
#
# - Investigate the website and the feature of the URLs.
# - Use `requests` to get the latitudes, longitudes, addresses, Unique IDs, store names, and openning hours of all the Starbucks scrapped as a DataFrame.
# - Visualise the stores on map.
#
# The boudanries to scrap:
#
# - north_bound = 60.8590 N
# - south_bound = 54.6356 N
# - west_bound = -7.385 W
# - east_bound = 1.7834 E

# %% [markdown]
# Since we need to scrap the data from different parts of the map, and each map's url is featured a unique centroid coordinate, we need to get a list of centroid coordinates in the large area before determining the urls.

# %%
north_bound = 60.8590
south_bound = 54.6356
west_bound = -7.385
east_bound = 1.7834

# determine the total number of grids
divisions_lat = 40
divisions_lon = 10

# Divide the maps into grids
step_lat = (north_bound - south_bound) / divisions_lat
step_lon = (east_bound - west_bound) / divisions_lon

# Get the centroid coordinates of each grid
centroids = []

# Generate grid centroids
for i in range(divisions_lat):
    for j in range(divisions_lon):
        # Calculate the centroid latitude
        centroid_lat = south_bound + step_lat * (i+ 0.5)
        # Calculate the centroid longitude
        centroid_lon = west_bound + step_lon * (j+ 0.5)    
        # Append the centroid (latitude, longitude) tuple to the centroids list
        centroids.append((centroid_lat, centroid_lon))

len(centroids), centroids[:5]
# Out:
# (400,
#  [(54.7133925, -6.9265799999999995),
#   (54.7133925, -6.00974),
#   (54.7133925, -5.0929),
#   (54.7133925, -4.17606),
#   (54.7133925, -3.25922)])

# %%
stores_data = []

base_url1 = 'https://www.starbucks.co.uk/api/v2/stores/?filter%5Bcoordinates%5D%5Blatitude%5D='
base_url2 = '&filter%5Bcoordinates%5D%5Blongitude%5D='
base_url3 = '&filter%5Bradius%5D=46.6'

for centroid in tqdm(centroids):
    # Format the request URL with the current centroid
    url = f"{base_url1}{centroid[0]}{base_url2}{centroid[1]}{base_url3}"
    response = requests.get(url)
    response.raise_for_status()  
    data = response.json()

    if data.get('data'):
        for store in data['data']:
            store_info = {
                'storeNumber': store['attributes']['storeNumber'],
                'name': store['attributes']['name'],
                'streetAddress': store['attributes']['address']['streetAddressLine1'],
                'city': store['attributes']['address']['city'],
                'postalCode': store['attributes']['address']['postalCode'],
                'latitude': store['attributes']['coordinates']['latitude'],
                'longitude': store['attributes']['coordinates']['longitude'],
                'isOpen': store['attributes']['isOpen'],
                'features': [feature['name'] for feature in store['attributes']['features']]
            }
            stores_data.append(store_info)

stores_df = pd.DataFrame(stores_data)
# Out:
# 100%|█████████████████████████████████████████| 400/400 [04:19<00:00,  1.54it/s]

# %%
stores_df = pd.DataFrame(stores_data)
# Drop duplicate rows based on the 'storeNumber' column because the same store might appear in responses for multiple centroids,  
# especially if the centroids overlap in their coverage of Starbucks locations.
stores_df_unique = stores_df.drop_duplicates(subset=['storeNumber']) 

print(len(stores_df_unique))

stores_df_unique
# Out:
# 224
#        storeNumber                            name  \
# 0     81125-310421     Magherafelt - Meadowlane SC
# 1     23407-230067  Londonderry Crescent Link (7B)
# 2     23413-230089  Londonderry Foyleside SC (Unit
# 3     58739-292992                        Richmond
# 4     23410-236917               Antrim Junction 1
# ...            ...                             ...
# 2477  54829-288559             Inverness - Rose St
# 2478  70443-305353  Inverness-New Look-Inverness R
# 2519  56614-290497         Peterhead Buchan Way DT
# 2552  57268-291315                  Elgin - A96 DT
# 2553  70444-308246               Elgin High Street
#
#                                           streetAddress         city  \
# 0     Unit 10 Meadowlane Shopping Centre Moneymore R...  Magherafelt
# 1                     Unit 7B Crescent Link Retail Park  Londonderry
# 2                                 Londenderry Foyleside  Londonderry
# 3                               Ferryquay Street, Derry       Antrim
# 4     Unit 50,  Junction One Retail Centre,  Ballyme...       Antrim
# ...                                                 ...          ...
# 2477                                        Rose Street    Inverness
# 2478                              Unit 1B West Seafield    Inverness
# 2519                                         Buchan Way    Peterhead
# 2552                                                A96        Elgin
# 2553                                    124 High Street        Elgin
#
#      postalCode  latitude  longitude isOpen  \
# 0       BT456PR  54.75457   -6.61099   True
# 1      BT47 6SA  54.99889   -7.27455   True
# 2      BT48 6XY  54.99450   -7.31838   True
# 3      BT48 6QP  54.99600   -7.32066   True
# 4      BT41 4JG  54.73045   -6.23192   True
# ...         ...       ...        ...    ...
# 2477    IV1 1NQ  57.48142   -4.22664   True
# 2478    IV2 7GD  57.48248   -4.17646   True
# 2519   AB42 3GT  57.48563   -1.80407   True
# 2552   IV30 8QN  57.64026   -3.26137   True
# 2553   IV30 1BW  57.64842   -3.31600   True
#
#                                                features
# 0                                [Mobile Order and Pay]
# 1     [Redeem Rewards, Wireless Hot-Spot, Mobile Ord...
# 2     [Redeem Rewards, Wireless Hot-Spot, Mobile Ord...
# 3                                [Mobile Order and Pay]
# 4     [Redeem Rewards, Wireless Hot-Spot, Mobile Ord...
# ...                                                 ...
# 2477  [Redeem Rewards, Wireless Hot-Spot, Oven - War...
# 2478  [Redeem Rewards, Wireless Hot-Spot, Oven - War...
# 2519  [Redeem Rewards, Drive-Thru Ordering, Mobile O...
# 2552  [Redeem Rewards, Wireless Hot-Spot, Drive-Thru...
# 2553  [Redeem Rewards, Wireless Hot-Spot, Oven - War...
#
# [224 rows x 9 columns]

# %%
m = folium.Map(location=[55, -2], zoom_start=6)

for index, row in stores_df_unique.iterrows():
    lat = row['latitude']
    lng = row['longitude']

    popup_text = row['name']
    
    folium.CircleMarker(
        location=[lat, lng],
        radius=5,
        color='green',
        fill=True,
        fill_color='green',
        fill_opacity=1,
        popup=folium.Popup(popup_text, parse_html=True) 
    ).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_888a51e7429c0cf1c6225497a8410089 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_888a51e7429c0cf1c6225497a8410089&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_888a51e7429c0cf1c6225497a8410089 = L.map(
#                 &quot;map_888a51e7429c0cf1c6225497a8410089&quot;,
#                 {
#                     center: [55.0, -2.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2fb52ebc5ec7a3db5e53f3168a4e039b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2fb52ebc5ec7a3db5e53f3168a4e039b.addTo(map_888a51e7429c0cf1c6225497a8410089);
#
#
#             var circle_marker_8c90aa64316229c49c36b9e7bf440cd9 = L.circleMarker(
#                 [54.75457, -6.61099],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_888a51e7429c0cf1c6225497a8410089);
#
#
#         var popup_11b1226b2a22461179cf247a0f604a3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60863a28e35dd5966ae5afabc1213bbb = $(`&lt;div id=&quot;html_60863a28e35dd5966ae5afabc1213bbb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Magherafelt - Meadowlane SC&lt;/div&gt;`)[0];
#                 popup_11b1226b2a22461179cf247a0f604a3c.setContent(html_60863a28e35dd5966ae5afabc1213bbb);
#
#
#
#         circle_marker_8c90aa64316229c49c36b9e7bf440cd9.bindPopup(popup_11b1226b2a22461179cf247a0f604a3c)
#         ;
#
#
#
#
#             var circle_marker_ea1fc678e6fe9605569901cbbff8019d = L.circleMarker(
#                 [54.99889, -7.27455],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_888a51e7429c0cf1c6225497a8410089);
#
#
#         var popup_3fbcda0b3c50c6ba402f3e820fc424da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f4b1ca682366c2af865d049e82c2909 = $(`&lt;div id=&quot;html_1f4b1ca682366c2af865d049e82c2909&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Londonderry Crescent Link (7B)&lt;/div&gt;`)[0];
#                 popup_3fbcda0b3c50c6ba402f3e820fc424da.setContent(html_1f4b1ca682366c2af865d049e82c2909);
#
#
#
#         circle_marker_ea1fc678e6fe9605569901cbbff8019d.bindPopup(popup_3fbcda0b3c50c6ba402f3e820fc424da)
#         ;
#
#
#
#
#             var circle_marker_b99ad66ca0eba66b4bb336f0b9e26320 = L.circleMarker(
#                 [54.9945, -7.31838],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_888a51e7429c0cf1c6225497a8410089);
#
#
#         var popup_07d8036cb05fac013c884729832ea5c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e54c0471e9ad272a868e252cdcd88a84 = $(`&lt;div id=&quot;html_e54c0471e9ad272a868e252cdcd88a84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Londonderry Foyleside SC (Unit&lt;/div&gt;`)[0];
#                 popup_07d8036cb05fac013c884729832ea5c5.setContent(html_e54c0471e9ad272a868e252cdcd88a84);
#
#
#
#         circle_marker_b99ad66ca0eba66b4bb336f0b9e26320.bindPopup(popup_07d8036cb05fac013c884729832ea5c5)
#         ;
#
#
#
#
#             var circle_marker_663d243ff8070b212
